# %%
import pandas as pd
import numpy as np
from transformers import pipeline
import re
import os
from tqdm import tqdm
import torch
from src.config import RAW_DATA_DIR, INTERIM_DATA_DIR

categories = {'order-modifications': ['item-additions',
  'item-removals',
  'quantity-adjustments',
  'late-modification-requests'],
 'order-cancellations': ['standard-cancellations',
  'urgent-cancellations',
  'rescheduled-orders'],
 'delivery-issues': ['late-deliveries',
  'missed-deliveries',
  'incomplete-deliveries',
  'damaged-goods',
  'delivery-confirmation-issues'],
 'pickup-scheduling-&-rescheduling': ['new-pickup-requests',
  'rescheduling-pickup',
  'missed-pickups',
  'pickup-policy-clarifications'],
 'product-availability-&-substitutions': ['stock-availability-inquiries',
  'out-of-stock-notifications',
  'product-substitution-requests',
  'special-item-requests'],
 'grant-&-billing-issues': ['grant-fund-usage',
  'incorrect-grant-deduction',
  'billing-discrepancies',
  'payment-&-credit-issues'],
 'training-&-account-access': ['training-signups',
  'missed-training-sessions',
  'login-issues',
  'new-user-account-requests'],
 'emergency-situations': ['weather-related-disruptions',
  'personal/organization-emergencies',
  'food-safety-concerns',
  'unexpected-facility-closures'],
 'special-requests': ['educational-materials',
  'large-event-orders',
  'holiday-&-seasonal-adjustments'],
 'technical-support': ['website-&-ordering-system-errors',
  'email-&-communication-issues',
  'data-entry-mistakes',
  'general-it-assistance'],
 'other': ['miscellaneous']}

def read_ticket_data(file_path):
    with open(file_path, 'r', encoding='utf-8', errors='replace') as file:
        content = file.read()
    
    # Split the content by the ticket separator
    tickets = content.split("END OF TICKET")
    
    # Remove empty tickets and strip whitespace
    tickets = [ticket.strip() for ticket in tickets if ticket.strip()]
    
    return tickets

def preprocess_ticket(ticket):
    if ticket.lower() == "nan" or ticket.strip() == "":
        return "other/miscellaneous"
    
    # Remove special characters and formatting
    ticket = re.sub(r'\{color:[^}]*\}|\{color\}|\{quote\}|\{adf\}.*?\{adf\}', ' ', ticket)
    ticket = re.sub(r'<[^>]*>', ' ', ticket)
    ticket = re.sub(r'!https?://[^\s!]*!', ' ', ticket)
    ticket = re.sub(r'\[[^\]]*\]', ' ', ticket)
    ticket = re.sub(r'https?://\S+', ' ', ticket)
    ticket = re.sub(r'\s+', ' ', ticket)
    
    return ticket.strip()

def generate_class_labels():
    labels = []
    for category, subcategories in categories.items():
        for subcategory in subcategories:
            labels.append(f"{category}/{subcategory}")
    return labels

def classify_ticket(ticket, classifier, class_labels):
    if ticket.lower() == "empty ticket":
        return "other/miscellaneous"
    
    # Use the classifier to predict the category
    result = classifier(ticket, class_labels, multi_label=False)
    return result['labels'][0]

# %%
tickets = read_ticket_data(RAW_DATA_DIR / "combined_ticket_data.txt")
preprocessed_tickets = [preprocess_ticket(ticket) for ticket in tickets]
class_labels = generate_class_labels()
    
print("Loading zero-shot classification model...")
classifier = pipeline("zero-shot-classification", 
                        model="facebook/bart-large-mnli",
                        device="cuda")
# Out:
# Loading zero-shot classification model...
# Device set to use cuda

# %%
result = classifier(preprocessed_tickets, class_labels, multi_label=False)

# %%
output = [o['labels'][0] for o in result]

# %%
pd.DataFrame(result).to_csv('raw_with_cat.csv', index=False)

# %%
raw_xl = pd.read_excel(RAW_DATA_DIR / 'cafb_data_case2.xlsx')
raw_xl
# Out:
#                                                Summary   Issue key  Issue id  \
# 0                                     SO-XXXXXX - TEST  PART1-5272     28196
# 1                                              test 10  PART1-3843     28206
# 2                                        Test 5 - PART  PART1-6049     28107
# 3                           Re: CAFB Pick Up TOMORROW   PART1-7176     65688
# 4                                            addition   PART1-6512     55866
# ..                                                 ...         ...       ...
# 995                           Produce Request SO192376  PART1-8375     80442
# 996                                    Got this vmail   PART1-7890     73968
# 997                  Prince George's Community College  PART1-5081     24725
# 998                               New Shopper Account   PART1-7182     65731
# 999  Hello, I am unable to pay for my order.  I kee...  PART1-6874     61335
#
#                    Issue Type  Status Project key     Project name Priority  \
# 0    [System] Service request  Closed       PART1  Partner Support   Medium
# 1    [System] Service request  Closed       PART1  Partner Support   Medium
# 2    [System] Service request  Closed       PART1  Partner Support   Medium
# 3    [System] Service request  Closed       PART1  Partner Support   Medium
# 4    [System] Service request  Closed       PART1  Partner Support   Medium
# ..                        ...     ...         ...              ...      ...
# 995  [System] Service request  Closed       PART1  Partner Support   Medium
# 996  [System] Service request  Closed       PART1  Partner Support   Medium
# 997  [System] Service request  Closed       PART1  Partner Support   Medium
# 998  [System] Service request  Closed       PART1  Partner Support   Medium
# 999  [System] Service request  Closed       PART1  Partner Support   Medium
#
#     Resolution Assignee  ... Comment.11 Comment.12 Comment.13 Comment.14  \
# 0         Done       BM  ...        NaN        NaN        NaN        NaN
# 1         Done       DH  ...        NaN        NaN        NaN        NaN
# 2         Done       DH  ...        NaN        NaN        NaN        NaN
# 3         Done       CH  ...        NaN        NaN        NaN        NaN
# 4         Done       CH  ...        NaN        NaN        NaN        NaN
# ..         ...      ...  ...        ...        ...        ...        ...
# 995       Done       CR  ...        NaN        NaN        NaN        NaN
# 996       Done       DH  ...        NaN        NaN        NaN        NaN
# 997       Done       DH  ...        NaN        NaN        NaN        NaN
# 998       Done       CR  ...        NaN        NaN        NaN        NaN
# 999       Done       CH  ...        NaN        NaN        NaN        NaN
#
#     Comment.15 Comment.16 Comment.17 Comment.18 Comment.19 Comment.20
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 995        NaN        NaN        NaN        NaN        NaN        NaN
# 996        NaN        NaN        NaN        NaN        NaN        NaN
# 997        NaN        NaN        NaN        NaN        NaN        NaN
# 998        NaN        NaN        NaN        NaN        NaN        NaN
# 999        NaN        NaN        NaN        NaN        NaN        NaN
#
# [1000 rows x 58 columns]

# %%
description = pd.Series(read_ticket_data(RAW_DATA_DIR / 'raw_description_processed.txt'), name='Desc')

# %%
main_cat = pd.Series([out.split('/')[0] for out in output], name='Main Category')
fine_cat = pd.Series([out.split('/')[1] for out in output], name='Sub-Category')
title = pd.Series(output, name='Title')
df = pd.concat((title, description, main_cat, fine_cat, raw_xl), axis=1)
df['Comments'] = df.filter(like='Comment').apply(lambda x: '\n'.join(x.dropna()), axis=1)
#df.to_csv(INTERIM_DATA_DIR / 'ticket_data.csv', index=False)

# %%
df = pd.read_csv(INTERIM_DATA_DIR / 'ticket_data.csv')

# %%
df.columns = df.columns.str.replace(r'^Custom field \((.*?)\)$', r'\1', regex=True)
df
# Out:
#                                                  Title  \
# 0                                  Other/Miscellaneous
# 1                                  Other/Miscellaneous
# 2                                  Other/Miscellaneous
# 3               Order Cancellations/Rescheduled Orders
# 4                   Order Modifications/Item Additions
# ..                                                 ...
# 995           Order Modifications/Quantity Adjustments
# 996                                Other/Miscellaneous
# 997                                Other/Miscellaneous
# 998  Pickup Scheduling & Rescheduling/New Pickup Re...
# 999  Technical Support/Website & Ordering System Er...
#
#                                                   Desc  \
# 0                                         Empty ticket
# 1                                         Empty ticket
# 2                                This is a description
# 3    Sent email Friday to cancel order Yvonne Brown...
# 4    Can you please add 25 cases of the following t...
# ..                                                 ...
# 995                                         Thank you!
# 996  Number: 301.648.4884 Hello! This is Christiana...
# 997                                       Empty ticket
# 998                                       Empty ticket
# 999  Hello, I am unable to pay for my order. I keep...
#
#                         Main Category                      Sub-Category  \
# 0                               Other                     Miscellaneous
# 1                               Other                     Miscellaneous
# 2                               Other                     Miscellaneous
# 3                 Order Cancellations                Rescheduled Orders
# 4                 Order Modifications                    Item Additions
# ..                                ...                               ...
# 995               Order Modifications              Quantity Adjustments
# 996                             Other                     Miscellaneous
# 997                             Other                     Miscellaneous
# 998  Pickup Scheduling & Rescheduling               New Pickup Requests
# 999                 Technical Support  Website & Ordering System Errors
#
#                                                Summary   Issue key  Issue id  \
# 0                                     SO-XXXXXX - TEST  PART1-5272     28196
# 1                                              test 10  PART1-3843     28206
# 2                                        Test 5 - PART  PART1-6049     28107
# 3                           Re: CAFB Pick Up TOMORROW   PART1-7176     65688
# 4                                            addition   PART1-6512     55866
# ..                                                 ...         ...       ...
# 995                           Produce Request SO192376  PART1-8375     80442
# 996                                    Got this vmail   PART1-7890     73968
# 997                  Prince George's Community College  PART1-5081     24725
# 998                               New Shopper Account   PART1-7182     65731
# 999  Hello, I am unable to pay for my order.  I kee...  PART1-6874     61335
#
#                    Issue Type  Status Project key  ... Comment.12 Comment.13  \
# 0    [System] Service request  Closed       PART1  ...        NaN        NaN
# 1    [System] Service request  Closed       PART1  ...        NaN        NaN
# 2    [System] Service request  Closed       PART1  ...        NaN        NaN
# 3    [System] Service request  Closed       PART1  ...        NaN        NaN
# 4    [System] Service request  Closed       PART1  ...        NaN        NaN
# ..                        ...     ...         ...  ...        ...        ...
# 995  [System] Service request  Closed       PART1  ...        NaN        NaN
# 996  [System] Service request  Closed       PART1  ...        NaN        NaN
# 997  [System] Service request  Closed       PART1  ...        NaN        NaN
# 998  [System] Service request  Closed       PART1  ...        NaN        NaN
# 999  [System] Service request  Closed       PART1  ...        NaN        NaN
#
#     Comment.14 Comment.15 Comment.16 Comment.17 Comment.18 Comment.19  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 995        NaN        NaN        NaN        NaN        NaN        NaN
# 996        NaN        NaN        NaN        NaN        NaN        NaN
# 997        NaN        NaN        NaN        NaN        NaN        NaN
# 998        NaN        NaN        NaN        NaN        NaN        NaN
# 999        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Comment.20                                           Comments
# 0          NaN  07/10/2023 01:07;5fb17b020dd553006f17ff0a;Hi D...
# 1          NaN  04/26/2024 07:53;557058:f58131cb-b67d-43c7-b30...
# 2          NaN  07/07/2023 06:59;5fb17b020dd553006f17ff0a;Work...
# 3          NaN  08/14/2024 09:57;557058:f58131cb-b67d-43c7-b30...
# 4          NaN  05/07/2024 12:17;557058:f58131cb-b67d-43c7-b30...
# ..         ...                                                ...
# 995        NaN  01/27/2025 11:47;712020:38c82492-84fe-40dc-890...
# 996        NaN  11/20/2024 11:12;712020:8bb74f6d-e197-4782-a07...
# 997        NaN  04/26/2023 10:20;61536ea272f6970069fc1dbd;Good...
# 998        NaN  08/14/2024 12:58;qm:65d20c5a-0c84-458e-8ce1-ad...
# 999        NaN  07/02/2024 12:08;qm:65d20c5a-0c84-458e-8ce1-ad...
#
# [1000 rows x 63 columns]

# %%
df['Main Category'] = df['Main Category'].str.lower().str.replace(r'\s+', '-', regex=True)
df['Sub-Category'] = df['Sub-Category'].str.lower().str.replace(r'\s+', '-', regex=True)
df
# Out:
#                                                  Title  \
# 0                                  Other/Miscellaneous
# 1                                  Other/Miscellaneous
# 2                                  Other/Miscellaneous
# 3               Order Cancellations/Rescheduled Orders
# 4                   Order Modifications/Item Additions
# ..                                                 ...
# 995           Order Modifications/Quantity Adjustments
# 996                                Other/Miscellaneous
# 997                                Other/Miscellaneous
# 998  Pickup Scheduling & Rescheduling/New Pickup Re...
# 999  Technical Support/Website & Ordering System Er...
#
#                                                   Desc  \
# 0                                         Empty ticket
# 1                                         Empty ticket
# 2                                This is a description
# 3    Sent email Friday to cancel order Yvonne Brown...
# 4    Can you please add 25 cases of the following t...
# ..                                                 ...
# 995                                         Thank you!
# 996  Number: 301.648.4884 Hello! This is Christiana...
# 997                                       Empty ticket
# 998                                       Empty ticket
# 999  Hello, I am unable to pay for my order. I keep...
#
#                         Main Category                      Sub-Category  \
# 0                               other                     miscellaneous
# 1                               other                     miscellaneous
# 2                               other                     miscellaneous
# 3                 order-cancellations                rescheduled-orders
# 4                 order-modifications                    item-additions
# ..                                ...                               ...
# 995               order-modifications              quantity-adjustments
# 996                             other                     miscellaneous
# 997                             other                     miscellaneous
# 998  pickup-scheduling-&-rescheduling               new-pickup-requests
# 999                 technical-support  website-&-ordering-system-errors
#
#                                                Summary   Issue key  Issue id  \
# 0                                     SO-XXXXXX - TEST  PART1-5272     28196
# 1                                              test 10  PART1-3843     28206
# 2                                        Test 5 - PART  PART1-6049     28107
# 3                           Re: CAFB Pick Up TOMORROW   PART1-7176     65688
# 4                                            addition   PART1-6512     55866
# ..                                                 ...         ...       ...
# 995                           Produce Request SO192376  PART1-8375     80442
# 996                                    Got this vmail   PART1-7890     73968
# 997                  Prince George's Community College  PART1-5081     24725
# 998                               New Shopper Account   PART1-7182     65731
# 999  Hello, I am unable to pay for my order.  I kee...  PART1-6874     61335
#
#                    Issue Type  Status Project key  ... Comment.12 Comment.13  \
# 0    [System] Service request  Closed       PART1  ...        NaN        NaN
# 1    [System] Service request  Closed       PART1  ...        NaN        NaN
# 2    [System] Service request  Closed       PART1  ...        NaN        NaN
# 3    [System] Service request  Closed       PART1  ...        NaN        NaN
# 4    [System] Service request  Closed       PART1  ...        NaN        NaN
# ..                        ...     ...         ...  ...        ...        ...
# 995  [System] Service request  Closed       PART1  ...        NaN        NaN
# 996  [System] Service request  Closed       PART1  ...        NaN        NaN
# 997  [System] Service request  Closed       PART1  ...        NaN        NaN
# 998  [System] Service request  Closed       PART1  ...        NaN        NaN
# 999  [System] Service request  Closed       PART1  ...        NaN        NaN
#
#     Comment.14 Comment.15 Comment.16 Comment.17 Comment.18 Comment.19  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 995        NaN        NaN        NaN        NaN        NaN        NaN
# 996        NaN        NaN        NaN        NaN        NaN        NaN
# 997        NaN        NaN        NaN        NaN        NaN        NaN
# 998        NaN        NaN        NaN        NaN        NaN        NaN
# 999        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Comment.20                                           Comments
# 0          NaN  07/10/2023 01:07;5fb17b020dd553006f17ff0a;Hi D...
# 1          NaN  04/26/2024 07:53;557058:f58131cb-b67d-43c7-b30...
# 2          NaN  07/07/2023 06:59;5fb17b020dd553006f17ff0a;Work...
# 3          NaN  08/14/2024 09:57;557058:f58131cb-b67d-43c7-b30...
# 4          NaN  05/07/2024 12:17;557058:f58131cb-b67d-43c7-b30...
# ..         ...                                                ...
# 995        NaN  01/27/2025 11:47;712020:38c82492-84fe-40dc-890...
# 996        NaN  11/20/2024 11:12;712020:8bb74f6d-e197-4782-a07...
# 997        NaN  04/26/2023 10:20;61536ea272f6970069fc1dbd;Good...
# 998        NaN  08/14/2024 12:58;qm:65d20c5a-0c84-458e-8ce1-ad...
# 999        NaN  07/02/2024 12:08;qm:65d20c5a-0c84-458e-8ce1-ad...
#
# [1000 rows x 63 columns]

# %%
#df.to_csv(INTERIM_DATA_DIR / 'ticket_data.csv', index=False)

# %%
df.columns
# Out:
# Index(['Title', 'Desc', 'Main Category', 'Sub-Category', 'Summary',
#        'Issue key', 'Issue id', 'Issue Type', 'Status', 'Project key',
#        'Project name', 'Priority', 'Resolution', 'Assignee',
#        'Reporter (Email)', 'Creator (Email)', 'Created', 'Updated',
#        'Last Viewed', 'Resolved', 'Due date', 'Description', 'Partner Names',
#        'Cause of issue', 'Record/Transaction ID', 'Region',
#        'Relevant Departments', 'Custom field (Relevant Departments).1',
#        'Request Category', 'Request Type', 'Request language',
#        'Resolution Action', 'Satisfaction rating', 'Satisfaction date',
#        'Source', 'Time to first response', 'Time to resolution',
#        'Work category', 'Status Category', 'Status Category Changed',
#        '[CHART] Date of First Response', 'Comment', 'Comment.1', 'Comment.2',
#        'Comment.3', 'Comment.4', 'Comment.5', 'Comment.6', 'Comment.7',
#        'Comment.8', 'Comment.9', 'Comment.10', 'Comment.11', 'Comment.12',
#        'Comment.13', 'Comment.14', 'Comment.15', 'Comment.16', 'Comment.17',
#        'Comment.18', 'Comment.19', 'Comment.20', 'Comments'],
#       dtype='object')

# %% [markdown]
# ### Clean Comments

# %%
from src.data.db import connect_to_db


conn = connect_to_db()
cursor = conn.cursor()

cursor.execute("""
            SELECT id, issue_key, body
            FROM jira_comments
               """)
comments = cursor.fetchall()

from src.data.preprocessing import clean_ticket

clean_comments = []
for id, issue_key, comment in comments:
    clean_comments.append((id, issue_key, clean_ticket(comment)))

from psycopg2.extras import execute_values

ids = (id for id, _, _ in clean_comments)
issue_keys = (issue_key for _, issue_key, _ in clean_comments)

execute_values(cursor,
    """
UPDATE jira_comments AS jc
SET body = updates.body
FROM (
    VALUES %s
) AS updates(id, issue_key, body)
WHERE jc.id = updates.id AND jc.issue_key = updates.issue_key
""",
clean_comments)
conn.commit()

# %%
from src.data.db import connect_to_db

conn = connect_to_db()
cursor = conn.cursor()
# with open("jira_issues.csv", "w") as f:
#     cursor.copy_expert("COPY jira_issues TO STDOUT WITH CSV HEADER", f)

# %%
cursor.execute("""
SELECT * FROM jira_issues WHERE issue_key = 'CAFBSS-1018';
""")

# %%
cursor.fetchall()
# Out:
# [(1001,
#   'CAFBSS-1018',
#   'order-modifications: quantity-adjustments',
#   None,
#   None,
#   'To Do',
#   datetime.datetime(2025, 4, 15, 16, 14, 32, 481000),
#   datetime.datetime(2025, 4, 15, 16, 14, 32, 556000),
#   None,
#   None,
#   None,
#   None,
#   'Story',
#   None,
#   None,
#   'CAFBSS',
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None,
#   None)]

# %%
from src.utils.constants import CATEGORIES



def prettify_category(s):
    s = s.replace('-', ' ')
    s = s.title()
    s = s.replace(' & ', ' & ')
    return s


for cat in CATEGORIES.keys():
    print(prettify_category(cat))
    for sub_cats in CATEGORIES[cat]:
        print(prettify_category(sub_cats))
# Out:
# Order Modifications
# Item Additions
# Item Removals
# Quantity Adjustments
# Late Modification Requests
# Order Cancellations
# Standard Cancellations
# Urgent Cancellations
# Rescheduled Orders
# Delivery Issues
# Late Deliveries
# Missed Deliveries
# Incomplete Deliveries
# Damaged Goods
# Delivery Confirmation Issues
# Pickup Scheduling & Rescheduling
# New Pickup Requests
# Rescheduling Pickup
# Missed Pickups
# Pickup Policy Clarifications
# Product Availability & Substitutions
# Stock Availability Inquiries
# Out Of Stock Notifications
# Product Substitution Requests
# Special Item Requests
# Grant & Billing Issues
# Grant Fund Usage
# Incorrect Grant Deduction
# Billing Discrepancies
# Payment & Credit Issues
# Training & Account Access
# Training Signups
# Missed Training Sessions
# Login Issues
# New User Account Requests
# Emergency Situations
# Weather Related Disruptions
# Personal/Organization Emergencies
# Food Safety Concerns
# Unexpected Facility Closures
# Special Requests
# Educational Materials
# Large Event Orders
# Holiday & Seasonal Adjustments
# Technical Support
# Website & Ordering System Errors
# Email & Communication Issues
# Data Entry Mistakes
# General It Assistance
# Other
# Miscellaneous

# %%
from src.data.jira import create_and_store_issue

issue_dict = {
    "project": "CAFBSS",
    "summary": "Order Modifications/Item Additions",
    "description": "Hello, mic testing 1 2 3",
    "issue_type": "Story",
    "priority": "High",
    "main_category": "order-modifications",
    "sub_category": "item-additions",
    "partner_names": "Hungry Terps",
}
response_dict = create_and_store_issue(issue_dict)
# Out:
# 2025-04-15 18:16:06.888 | INFO     | src.config:<module>:11 - PROJ_ROOT path is: /home/harshavardhan-patil/Work/Projects/cafb-ai
# Error getting current user: 'name'
# Created new issue CAFBSS-1022
# Stored issue CAFBSS-1022 in database

# %%
issue = response_dict['new_issue']

# %%
from src.utils.constants import JIRA_FIELD_MAPPING

issue.get_field(JIRA_FIELD_MAPPING['main_category'])[0]
# Out:
# 'order-modifications'

# %%
issue.key
# Out:
# 'CAFBSS-1022'

# %%
issue.permalink()
# Out:
# 'https://cafb-hungerbangers.atlassian.net/browse/CAFBSS-1022'

# %%
from src.data.jira import get_issue_kb
from src.data.db import connect_to_db

issue_key = 'CAFBSS-1028'
get_issue_kb(issue_key)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 5
#       2 from src.data.db import connect_to_db
#       4 issue_key = 'CAFBSS-1028'
# ----> 5 get_issue_kb(issue_key)
#
# File ~/Work/Projects/cafb-ai/src/data/jira.py:181, in get_issue_kb(issue_key)
#     179 result = cursor.fetchone()
#     180 conn.close
# --> 181 return result[0]
#
# TypeError: 'NoneType' object is not subscriptable

# %%
conn = connect_to_db()
cursor = conn.cursor()

cursor.execute(
    """
    SELECT main_category, sub_category
    FROM jira_issues
    WHERE issue_key = %s
    """,
    (issue_key,)
)

cursor.fetchone()
# Out:
# ('order-cancellations', 'standard-cancellations')
